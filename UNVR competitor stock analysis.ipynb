# %% [markdown]
# ## Competitor of UNVR Stock Comparison Analysis

# %% [markdown]
# #### Import Dependencies

# %%
import datetime as dt
import pandas as pd
import yfinance as yf

# %% [markdown]
# #### Specify Date Range for Analysis

# %%
end = dt.datetime.now()
start = dt.datetime(2017, 1, 1)
end, start
# Out:
# (datetime.datetime(2026, 2, 15, 22, 2, 2, 227654),
#  datetime.datetime(2017, 1, 1, 0, 0))

# %% [markdown]
# #### Select the Stocks/Tickers Data

# %%
stocklist = ['UNVR', 'MYOR', 'ICBP']
stocks = [i + '.JK' for i in stocklist]
stocks
# Out:
# ['UNVR.JK', 'MYOR.JK', 'ICBP.JK']

# %%
df = yf.download(stocks, start, end)
df.head()
# Out:
# [*********************100%***********************]  3 of 3 completed
# Price             Close                                   High               \
# Ticker          ICBP.JK      MYOR.JK      UNVR.JK      ICBP.JK      MYOR.JK
# Date
# 2017-01-02  7089.163086  1428.172363  5740.632324  7089.163086  1428.172363
# 2017-01-03  7109.831055  1519.332397  5744.331055  7130.499168  1736.379883
# 2017-01-04  7109.831055  1545.377930  5947.769531  7233.839736  1597.469321
# 2017-01-05  7089.163086  1519.332397  5999.552734  7192.503656  1558.400945
# 2017-01-06  7047.826660  1523.673218  6006.951172  7151.167227  1536.696066
#
# Price                            Low                                   Open  \
# Ticker          UNVR.JK      ICBP.JK      MYOR.JK      UNVR.JK      ICBP.JK
# Date
# 2017-01-02  5740.632324  7089.163086  1428.172363  5740.632324  7089.163086
# 2017-01-03  5799.813969  6944.486146  1428.172454  5740.632194  7027.158601
# 2017-01-04  5969.962701  7089.162941  1467.240843  5748.031002  7089.162941
# 2017-01-05  5999.552734  7068.494972  1519.332397  5921.876651  7109.831200
# 2017-01-06  6058.735234  7047.826660  1501.968471  5892.286464  7151.167227
#
# Price                                    Volume
# Ticker          MYOR.JK      UNVR.JK    ICBP.JK   MYOR.JK   UNVR.JK
# Date
# 2017-01-02  1428.172363  5740.632324        0.0         0         0
# 2017-01-03  1428.172454  5770.223081  2040600.0  10240300   5014500
# 2017-01-04  1519.332234  5748.031002  4027100.0   3980400  10642000
# 2017-01-05  1545.378096  5992.155012  3970900.0    542000  10493500
# 2017-01-06  1536.696066  5962.564833  1497300.0   1006200   5400500

# %% [markdown]
# #### Access Close Price Attributes for use on graphs.

# %%
Close = df.Close
Close.head()
# Out:
# Ticker          ICBP.JK      MYOR.JK      UNVR.JK
# Date
# 2017-01-02  7089.163086  1428.172363  5740.632324
# 2017-01-03  7109.831055  1519.332397  5744.331055
# 2017-01-04  7109.831055  1545.377930  5947.769531
# 2017-01-05  7089.163086  1519.332397  5999.552734
# 2017-01-06  7047.826660  1523.673218  6006.951172

# %% [markdown]
# #### Plotting with Matplotlib (Price Close movement Comparison)

# %%
Close.plot(figsize = (12, 8))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #### Plotting with Plotly (Price Close movement Comparison)

# %%
import plotly.offline as pyo
pyo.init_notebook_mode(connected=True)

pd.options.plotting.backend = 'plotly'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
Close.plot()
# Out:
# <div>                            <div id="53e24007-dafe-432c-b38d-519c0cad016b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53e24007-dafe-432c-b38d-519c0cad016b")) {                    Plotly.newPlot(                        "53e24007-dafe-432c-b38d-519c0cad016b",                        [{"hovertemplate":"Ticker=ICBP.JK\u003cbr\u003eDate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ICBP.JK","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"ICBP.JK","showlegend":true,"x":["2017-01-02T00:00:00","2017-01-03T00:00:00","2017-01-04T00:00:00","2017-01-05T00:00:00","2017-01-06T00:00:00","2017-01-09T00:00:00","2017-01-10T00:00:00","2017-01-11T00:00:00","2017-01-12T00:00:00","2017-01-13T00:00:00","2017-01-16T00:00:00","2017-01-17T00:00:00","2017-01-18T00:00:00","2017-01-19T00:00:00","2017-01-20T00:00:00","2017-01-23T00:00:00","2017-01-24T00:00:00","2017-01-25T00:00:00","2017-01-26T00:00:00","2017-01-27T00:00:00","2017-01-30T00:00:00","2017-01-31T00:00:00","2017-02-01T00:00:00","2017-02-02T00:00:00","2017-02-03T00:00:00","2017-02-06T00:00:00","2017-02-07T00:00:00","2017-02-08T00:00:00","2017-02-09T00:00:00","2017-02-10T00:00:00","2017-02-13T00:00:00","2017-02-14T00:00:00","2017-02-15T00:00:00","2017-02-16T00:00:00","2017-02-17T00:00:00","2017-02-20T00:00:00","2017-02-21T00:00:00","2017-02-22T00:00:00","2017-02-23T00:00:00","2017-02-24T00:00:00","2017-02-27T00:00:00","2017-02-28T00:00:00","2017-03-01T00:00:00","2017-03-02T00:00:00","2017-03-03T00:00:00","2017-03-06T00:00:00","2017-03-07T00:00:00","2017-03-08T00:00:00","2017-03-09T00:00:00","2017-03-10T00:00:00","2017-03-13T00:00:00","2017-03-14T00:00:00","2017-03-15T00:00:00","2017-03-16T00:00:00","2017-03-17T00:00:00","2017-03-20T00:00:00","2017-03-21T00:00:00","2017-03-22T00:00:00","2017-03-23T00:00:00","2017-03-24T00:00:00","2017-03-27T00:00:00","2017-03-29T00:00:00","2017-03-30T00:00:00","2017-03-31T00:00:00","2017-04-03T00:00:00","2017-04-04T00:00:00","2017-04-05T00:00:00","2017-04-06T00:00:00","2017-04-07T00:00:00","2017-04-10T00:00:00","2017-04-11T00:00:00","2017-04-12T00:00:00","2017-04-13T00:00:00","2017-04-17T00:00:00","2017-04-18T00:00:00","2017-04-19T00:00:00","2017-04-20T00:00:00","2017-04-21T00:00:00","2017-04-25T00:00:00","2017-04-26T00:00:00","2017-04-27T00:00:00","2017-04-28T00:00:00","2017-05-02T00:00:00","2017-05-03T00:00:00","2017-05-04T00:00:00","2017-05-05T00:00:00","2017-05-08T00:00:00","2017-05-09T00:00:00","2017-05-10T00:00:00","2017-05-12T00:00:00","2017-05-15T00:00:00","2017-05-16T00:00:00","2017-05-17T00:00:00","2017-05-18T00:00:00","2017-05-19T00:00:00","2017-05-22T00:00:00","2017-05-23T00:00:00","2017-05-24T00:00:00","2017-05-26T00:00:00","2017-05-29T00:00:00","2017-05-30T00:00:00","2017-05-31T00:00:00","2017-06-01T00:00:00","2017-06-02T00:00:00","2017-06-05T00:00:00","2017-06-06T00:00:00","2017-06-07T00:00:00","2017-06-08T00:00:00","2017-06-09T00:00:00","2017-06-12T00:00:00","2017-06-13T00:00:00","2017-06-14T00:00:00","2017-06-15T00:00:00","2017-06-16T00:00:00","2017-06-19T00:00:00","2017-06-20T00:00:00","2017-06-21T00:00:00","2017-06-22T00:00:00","2017-06-23T00:00:00","2017-06-26T00:00:00","2017-06-27T00:00:00","2017-06-28T00:00:00","2017-06-29T00:00:00","2017-06-30T00:00:00","2017-07-03T00:00:00","2017-07-04T00:00:00","2017-07-05T00:00:00","2017-07-06T00:00:00","2017-07-07T00:00:00","2017-07-10T00:00:00","2017-07-11T00:00:00","2017-07-12T00:00:00","2017-07-13T00:00:00","2017-07-14T00:00:00","2017-07-17T00:00:00","2017-07-18T00:00:00","2017-07-19T00:00:00","2017-07-20T00:00:00","2017-07-21T00:00:00","2017-07-24T00:00:00","2017-07-25T00:00:00","2017-07-26T00:00:00","2017-07-27T00:00:00","2017-07-28T00:00:00","2017-07-31T00:00:00","2017-08 ...

# %% [markdown]
# #### Plotting with Plotly (Growth Percentage Comparison)

# %%
pct_growth = Close.ffill().pct_change(fill_method=None)
pct_growth = (1 + pct_growth).cumprod() - 1
pct_growth.tail()
# Out:
# Ticker       ICBP.JK   MYOR.JK   UNVR.JK
# Date
# 2026-02-09  0.139063  0.743487 -0.599347
# 2026-02-10  0.146116  0.652462 -0.599347
# 2026-02-11  0.153169  0.659464 -0.606315
# 2026-02-12  0.156695  0.617452 -0.599347
# 2026-02-13  0.156695  0.575440 -0.599347

# %%
pct_growth.plot (title='Growth percetage Comparison : UNVR vs ICBP vs MYOR')
# Out:
# <div>                            <div id="081af23e-8292-4173-b3be-bf6f3e9c78ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("081af23e-8292-4173-b3be-bf6f3e9c78ae")) {                    Plotly.newPlot(                        "081af23e-8292-4173-b3be-bf6f3e9c78ae",                        [{"hovertemplate":"Ticker=ICBP.JK\u003cbr\u003eDate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ICBP.JK","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"ICBP.JK","showlegend":true,"x":["2017-01-02T00:00:00","2017-01-03T00:00:00","2017-01-04T00:00:00","2017-01-05T00:00:00","2017-01-06T00:00:00","2017-01-09T00:00:00","2017-01-10T00:00:00","2017-01-11T00:00:00","2017-01-12T00:00:00","2017-01-13T00:00:00","2017-01-16T00:00:00","2017-01-17T00:00:00","2017-01-18T00:00:00","2017-01-19T00:00:00","2017-01-20T00:00:00","2017-01-23T00:00:00","2017-01-24T00:00:00","2017-01-25T00:00:00","2017-01-26T00:00:00","2017-01-27T00:00:00","2017-01-30T00:00:00","2017-01-31T00:00:00","2017-02-01T00:00:00","2017-02-02T00:00:00","2017-02-03T00:00:00","2017-02-06T00:00:00","2017-02-07T00:00:00","2017-02-08T00:00:00","2017-02-09T00:00:00","2017-02-10T00:00:00","2017-02-13T00:00:00","2017-02-14T00:00:00","2017-02-15T00:00:00","2017-02-16T00:00:00","2017-02-17T00:00:00","2017-02-20T00:00:00","2017-02-21T00:00:00","2017-02-22T00:00:00","2017-02-23T00:00:00","2017-02-24T00:00:00","2017-02-27T00:00:00","2017-02-28T00:00:00","2017-03-01T00:00:00","2017-03-02T00:00:00","2017-03-03T00:00:00","2017-03-06T00:00:00","2017-03-07T00:00:00","2017-03-08T00:00:00","2017-03-09T00:00:00","2017-03-10T00:00:00","2017-03-13T00:00:00","2017-03-14T00:00:00","2017-03-15T00:00:00","2017-03-16T00:00:00","2017-03-17T00:00:00","2017-03-20T00:00:00","2017-03-21T00:00:00","2017-03-22T00:00:00","2017-03-23T00:00:00","2017-03-24T00:00:00","2017-03-27T00:00:00","2017-03-29T00:00:00","2017-03-30T00:00:00","2017-03-31T00:00:00","2017-04-03T00:00:00","2017-04-04T00:00:00","2017-04-05T00:00:00","2017-04-06T00:00:00","2017-04-07T00:00:00","2017-04-10T00:00:00","2017-04-11T00:00:00","2017-04-12T00:00:00","2017-04-13T00:00:00","2017-04-17T00:00:00","2017-04-18T00:00:00","2017-04-19T00:00:00","2017-04-20T00:00:00","2017-04-21T00:00:00","2017-04-25T00:00:00","2017-04-26T00:00:00","2017-04-27T00:00:00","2017-04-28T00:00:00","2017-05-02T00:00:00","2017-05-03T00:00:00","2017-05-04T00:00:00","2017-05-05T00:00:00","2017-05-08T00:00:00","2017-05-09T00:00:00","2017-05-10T00:00:00","2017-05-12T00:00:00","2017-05-15T00:00:00","2017-05-16T00:00:00","2017-05-17T00:00:00","2017-05-18T00:00:00","2017-05-19T00:00:00","2017-05-22T00:00:00","2017-05-23T00:00:00","2017-05-24T00:00:00","2017-05-26T00:00:00","2017-05-29T00:00:00","2017-05-30T00:00:00","2017-05-31T00:00:00","2017-06-01T00:00:00","2017-06-02T00:00:00","2017-06-05T00:00:00","2017-06-06T00:00:00","2017-06-07T00:00:00","2017-06-08T00:00:00","2017-06-09T00:00:00","2017-06-12T00:00:00","2017-06-13T00:00:00","2017-06-14T00:00:00","2017-06-15T00:00:00","2017-06-16T00:00:00","2017-06-19T00:00:00","2017-06-20T00:00:00","2017-06-21T00:00:00","2017-06-22T00:00:00","2017-06-23T00:00:00","2017-06-26T00:00:00","2017-06-27T00:00:00","2017-06-28T00:00:00","2017-06-29T00:00:00","2017-06-30T00:00:00","2017-07-03T00:00:00","2017-07-04T00:00:00","2017-07-05T00:00:00","2017-07-06T00:00:00","2017-07-07T00:00:00","2017-07-10T00:00:00","2017-07-11T00:00:00","2017-07-12T00:00:00","2017-07-13T00:00:00","2017-07-14T00:00:00","2017-07-17T00:00:00","2017-07-18T00:00:00","2017-07-19T00:00:00","2017-07-20T00:00:00","2017-07-21T00:00:00","2017-07-24T00:00:00","2017-07-25T00:00:00","2017-07-26T00:00:00","2017-07-27T00:00:00","2017-07-28T00:00:00","2017-07-31T00:00:00","2017-08 ...

# %% [markdown]
# #### Gain Insights Quickly with Pandas

# %%
Close[Close.index > end - dt.timedelta(days=100)].describe(percentiles = [0.1, 0.5, 0.9])
# Out:
# Ticker      ICBP.JK      MYOR.JK      UNVR.JK
# count     65.000000    65.000000    65.000000
# mean    8224.230769  2177.538462  2445.767465
# std      205.013778    98.963863   211.418698
# min     7675.000000  2020.000000  1860.000000
# 10%     8000.000000  2094.000000  2096.000000
# 50%     8225.000000  2150.000000  2513.992432
# 90%     8505.000000  2328.000000  2635.815137
# max     8650.000000  2490.000000  2770.000000

# %% [markdown]
# #### Risk & Return Analysis

# %% [markdown]
# ##### Return Analysis

# %%
df_return = Close.pct_change()
avg_return = df_return.mean()
print(avg_return)
# Out:
# Ticker
# ICBP.JK    0.000202
# MYOR.JK    0.000414
# UNVR.JK   -0.000169
# dtype: float64
# C:\Users\HP\AppData\Local\Temp\ipykernel_11684\2428513577.py:1: FutureWarning:
#
# The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.

# %% [markdown]
# ##### Risk Analysis

# %%
risk = df_return.std()
print(risk)
# Out:
# Ticker
# ICBP.JK    0.016596
# MYOR.JK    0.020747
# UNVR.JK    0.021962
# dtype: float64

# %% [markdown]
# #### Comparison of Stock Characteristics from the Histogram Chart

# %%
Close.plot()
Close['MYOR.JK'].pct_change().plot(kind='hist')

# %%
Close.plot()
Close['UNVR.JK'].pct_change().plot(kind='hist')

# %%
Close.plot()
Close['ICBP.JK'].pct_change().plot(kind='hist')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11684\1717026065.py:2: FutureWarning:
#
# The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
